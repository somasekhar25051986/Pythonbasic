# %%
'''Note: For each theory Question, give at least one example.'''

# %% [markdown]
# 1. What is the difference between a function and a method in Python?
#   - Function and method, both are block of reusable codedesigned to perform specific tasks.
#    - Functionsare defined independently, accepts arguments and return values.
#    Example:
#    def add(a,b):
#      return a+b
#    print(add(2,3))
#    - Methods are defined inside a class and can be called with reference to object/class
#    class ArithmeticOperation:
#      def __init__(self):
#        print("Inside Arithmetic Operation class")
#
#      def add(self, x,y):
#        return self.x+self.y
#
#   arithOps = ArithmeticOperation()
#   print(arithOps.add(4,5))

# %% [markdown]
# 2. Explain the concept of function arguments and parameters in Python.
#  - 1. without arguments
#      def greet():
#        print("Hello")
#      greet()
#   - 2. with parameters
#      def add(a,b):
#        return a+b
#      add(3,4)
#   - 3. with default arguments
#     def power(x,p=2):
#       return x**p
#     power(3)
#     power(3,3)
#   - 4. keyword arguments
#     def multiply(a,b):
#       return a*b
#     multipley(b=4,a=2)
#   - 5. variable number of arguments
#     def sum(*args):
#       sum=0
#       for n in args:
#         sum +=n
#       return sum
#     print(sum(1,2,3,4))
#   - 6. multiple keyword arguments
#     def person(**kwargs):
#       print(f"My name is {name} and I am {age}years old")
#     person(name="John",age=30)
#   - 7. lambda functions
#     square = lambda x:x*X
#     print(square(5))

# %% [markdown]
# 3. What are the different ways to define and call a function in Python?
#   - Functions are defined using the def keyword, but they can also be created dynamically or using anonymous functions
#   1. Standard way(using def keyword)
#     def add(a,b):
#       return a+b
#     print(add(3,4))
#   2. Lambda functions(Anonymous Functions): defined using lambda keyword
#     square = lambda x:x*X
#     print(square(5))
#   3. Nested Functions: Functions can be defined inside another function
#     def check(x):
#       if x<0:
#         return "negative"
#       return "positive"
#     print(check(-1))
#   4. Function Objects
#     greet():
#       print("Hello")
#     greet1 = greet
#     print(greet1())

# %% [markdown]
# 4. What is the purpose of the `return` statement in a Python function?
#   -  To give back a result from a function
#      def add(a,b):
#        return a+b
#      print(add(3,4))
#   - To exit a function early
#     def check(x):
#       if x<0:
#         return "negative"
#       return "positive"
#   - Return multiple values
#     def daysofWeek():
#       return "Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"
#
#     day1, day2, day3,day4,day5,day6,day7 = daysofweek()

# %% [markdown]
# 5. What are iterators in Python and how do they differ from iterables?
#   - An iterabel is any python object/sequential structure/data structure that is capable of returning its members one at a time
#    permitting it to be iterated over a ina for loop
#    example list,tuple
#     - numbers = [10,20,30] #numbers is iterable
#   - An Iterator is an object representing a stream of data and which can return the data one by one when we call next()
#   An Iterator must implement:
#     - __iter__(): return self
#     - __next__(): return next value or raises StopIteration.
#    it = iter(numbers)
#    print(next(it))

# %% [markdown]
# 6. Explain the concept of generators in Python and how they are defined.
#   - Generator is a special kind of iterable that lets you produce a sequence of values lazily(values are generated only when needed) which avoid storing the whole sequence in memory.
#   Generator is:
#     - like a function that returns values one at a time
#     - Suspends its execution each time it produces a value
#     - resumes from where it left off.
#   - Generators are based on thekeyword **yield**.
#     def square_generator(n):
#       for i in range(n):
#         yield i**2
#
#     gen = square_generator(10)
#     print(next(gen))

# %% [markdown]
# 7. What are the advantages of using generators over regular functions?
#   - 1. less memory usage: No need to store the whole sequence
#     2. This returns single value
#     3. excution is faster

# %% [markdown]
# 8. What is a lambda function in Python and when is it typically used?
#   - Lambda function in python is small, anonymous(unnamed) function which is defined using lambda keyword indtead of def.
#   - Typically used with single expression for short period.

# %% [markdown]
# 9. Explain the purpose and usage of the `map()` function in Python.
#   - The map() function in Python is a power build in utility used to apply a specific function to every item in an iterable(such as list,tuple,etc) and returns an iterator of the result.
#   - **Purpose**
#     - The main purpose of map() is to transform data efficiently without needing to write an explicit for loop.
#     - It allows for a functional programming style by abstracting the process of iterating over a sequence and modifying each element individually.
#   - **Syntax**
#     - map(function,iterable,..)
#  - Example
#    - def multiplyBy2(x):
#      - return x*2
#    - numbers = [10,2,15,20]
#    - numbersx2 = list(map(multiplyBy2,numbers))
#    - print(numbersx2)

# %% [markdown]
# 10. What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?
#
#  (Attach paper image for this answer) in doc or colab notebook.'
#
#  <img src="data:image/png;base64,..." alt="description of image">

# %%
''' Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in
the list.'''
def sum_even_numbers(*args):
  sum=0
  for n in args:
    if n%2==0:
      sum +=n
  return sum
print(sum_even_numbers(1,2,3,4))
# Out:
# 6

# %%
'''2. Create a Python function that accepts a string and returns the reverse of that string.'''
def reverse_string(str):
  return str[::-1]

print(reverse_string("Hello"))
# Out:
# olleH

# %%
'''3. Implement a Python function that takes a list of integers and returns a new list containing the squares of
each number.'''
def square_list(lst):
  return [x*x for x in lst]
print(square_list([1,2,3,4]))
# Out:
# [1, 4, 9, 16]

# %%
'''4. Write a Python function that checks if a given number is prime or not from 1 to 200.'''
def is_prime(n):
  if n<2:
    return False
  for i in range(2,int(n**0.5)+1):
    if n%i==0:
      return False
  return True

print(is_prime(17))
# Out:
# True

# %%
'''5. Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of
terms.'''
class fibonacci:
  def __init__(self,value):
    self.value=value
    self.count = 0
    self.a=0
    self.b=1

  def __iter__(self):
    return self

  def __next__(self):
      if self.count >= self.value:
        raise StopIteration
      elif self.count == 0:
        self.count +=1
        return self.a
      elif self.count == 1:
        self.count +=1
        return self.b

      self.count +=1
      self.a,self.b=self.b,self.a+self.b
      return self.b


fib = fibonacci(7)
for i in fib:
  print(i)
# Out:
# 0
# 1
# 1
# 2
# 3
# 5
# 8

# %%
'''6. Write a generator function in Python that yields the powers of 2 up to a given exponent.'''
def powerOf2(n):
  for i in range(n+1):
    yield 2**i

for i in powerOf2(5):
  print(i)
# Out:
# 1
# 2
# 4
# 8
# 16
# 32

# %%
'''7. Implement a generator function that reads a file line by line and yields each line as a string.'''
text = "Hello! I am Somasekhar.\nThis is Functions Assignment.\nToday is Wednesday."
with open("textfile.txt","w") as f:
  f.write(text)

def read_file(filename):
  with open("textfile.txt","r") as f:
    lines = f.readlines()
    for line in  lines:
      yield line

for line in read_file("textfile.txt"):
  print(line,end="")
# Out:
# Hello! I am Somasekhar.
# This is Functions Assignment.
# Today is Wednesday.

# %%
'''8. Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.'''
lituple = [("apple",10),("banana",50),("cherry",30),("date",1)]
lituple.sort(key=lambda x:x[1])
print(lituple)
# Out:
# [('date', 1), ('apple', 10), ('cherry', 30), ('banana', 50)]

# %%
'''9. Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit.'''
celsius = [39.2,36.5,37.3,37.8]
fahrenheit = list(map(lambda c:(c*9/5)+32,celsius))
print(fahrenheit)
# Out:
# [102.56, 97.7, 99.14, 100.03999999999999]

# %%
'''10. Create a Python program that uses `filter()` to remove all the vowels from a given string.'''
givstr = input("Enter a String to remove vowels: ")
vowels = ['a','e','i','o','u','A','E','I','O','U']
result = list(filter(lambda x:x not in vowels,givstr))
print("".join(result))
# Out:
# Enter a String to remove vowelsSomasekhar
# Smskhr

# %%
'''11) Imagine an accounting routine used in a book shop. It works on a list with sublists, which look like this:


Write a Python program, which returns a list with 2-tuples. Each tuple consists of the order number and the
product of the price per item and the quantity. The product should be increased by 10,- € if the value of the
order is smaller than 100,00 €.

Write a Python program using lambda and map.'''
data = [
    [34587,"Learnin Pyhton, Mark Lutz",4, 40.95],
    [98762,"Programming Python, Mark Lutz",5,56.80],
    [77226,"Head First Python, Paul Barry",3,32.95],
    [88112,"Einführung in Python3, Bernd Klein",3,24.99]
]

calculate_total = lambda item:(item[0],round((item[2]*item[3])+(10 if item[2]*item[3]<100 else 0),2))
result = list(map(calculate_total,data))
print(result)
# Out:
# [(34587, 163.8), (98762, 284.0), (77226, 108.85), (88112, 84.97)]

# %% [markdown]
# <img src="data:image/png;base64,..." alt="description of image" width="500"/>
